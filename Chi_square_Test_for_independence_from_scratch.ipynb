# %%
# H0=PClass and Survived are independent Columns

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2
from scipy.stats import chi2_contingency
# Load the Titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=pd.crosstab(data['Survived'],data['Pclass'],margins=True, margins_name='Total')
df_copy=df.copy()
df
# Out:
# Pclass      1    2    3  Total
# Survived
# 0          80   97  372    549
# 1         136   87  119    342
# Total     216  184  491    891

# %%
df_copy
# Out:
# Pclass      1    2    3  Total
# Survived
# 0          80   97  372    549
# 1         136   87  119    342
# Total     216  184  491    891

# %%
Grand_Total=df.loc["Total","Total"]
for i in range(df.shape[0]-1):
    for j in range(1,df.shape[1]):
      df_copy.loc[i,j]=(df.loc[i,'Total']*df.loc['Total',j]/Grand_Total)
df_copy
# Out:
# Pclass             1           2           3  Total
# Survived
# 0         133.090909  113.373737  302.535354    549
# 1          82.909091   70.626263  188.464646    342
# Total     216.000000  184.000000  491.000000    891

# %%
X=0
for i in range(df.shape[0]-1):
    for j in range(1,df.shape[1]):
      X+=(df.loc[i,j]-df_copy.loc[i,j])**2/df_copy.loc[i,j]
print(X)
# Out:
# 102.88898875696056

# %%
degree_of_freedom=df.shape[1]-2
p_value=chi2.sf(X,df=degree_of_freedom)
print(p_value)
# Out:
# 4.549251711298793e-23

# %%
alpha=0.05
if(p_value<alpha):
    print('Reject the Null Hypothesis')
else:
     print('Failed to Reject the Null Hypothesis')
# Out:
# Reject the Null Hypothesis

# %%
contingency_table = pd.crosstab(data['Survived'], data['Pclass'])
contingency_table
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# Using chi2_contingency

# %%
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("\nChi-Square Statistic: {:.2f}".format(chi2))
print("P-value: {:.4f}".format(p_value))
print("Degrees of Freedom: {}".format(dof))
print("Expected Frequencies: \n{}".format(expected))
# Out:
# Chi-Square Statistic: 102.89
# P-value: 0.0000
# Degrees of Freedom: 2
# Expected Frequencies:
# [[133.09090909 113.37373737 302.53535354]
#  [ 82.90909091  70.62626263 188.46464646]]

# %%
alpha=0.05
if(p_value<alpha):
    print('Reject the Null Hypothesis')
else:
     print('Failed to Reject the Null Hypothesis')
# Out:
# Reject the Null Hypothesis
