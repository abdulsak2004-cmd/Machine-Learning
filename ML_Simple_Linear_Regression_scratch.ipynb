# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('placement.csv')
data.head()
x=data[['cgpa']]
y=data['package']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
class SLR:
    def __init__(self):
        self.m=0
        self.b=0

    def fit(self, x, y):
        num=0
        denom=0
        for i in range(x.shape[0]):
            num=num + (x[i]-x.mean()) * (y[i]-y.mean())
            denom=denom + np.square(x[i]-x.mean())

        self.m=num/denom
        self.b=y.mean()-(self.m*x.mean())

    def predict(self, x):
        return self.m*x + self.b

    def display_parameters(self):
        print('slope m: ',self.m)
        print('intercept b: ',self.b)

# %%
X_train=x_train['cgpa'].values
Y_train=y_train.values

# %%
lr=SLR()

# %%
lr.fit(X_train,Y_train)

# %%
lr.predict(8.5)
# Out:
# np.float64(3.846479851870197)

# %%
lr.display_parameters()
# Out:
# slope m:  0.5579519734250721
# intercept b:  -0.8961119222429152
