# %% [markdown]
# Use the famous boston dataset and find out if there is multicollinearity or not. If there is multicollinearity try to remove it with help of steps taught in the session.

# %%
# Link - https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
data = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
X=data[['crim',"zn","indus","chas","nox","rm",'age','dis','rad','tax','ptratio','b','lstat']]
y=data['medv']
model_all=sm.OLS(y,X).fit()
print(model_all.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              891.3
# Date:                Sun, 23 Aug 2026   Prob (F-statistic):                        0.00
# Time:                        05:51:07   Log-Likelihood:                         -1523.8
# No. Observations:                 506   AIC:                                      3074.
# Df Residuals:                     493   BIC:                                      3128.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
data=data.drop(columns=['rad','indus','nox','age'])

# %%
X=data[['crim',"zn","chas","rm",'dis','tax','ptratio','b','lstat']]
y=data['medv']
model_all=sm.OLS(y,X).fit()
print(model_all.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.958
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              1272.
# Date:                Sun, 23 Aug 2026   Prob (F-statistic):                        0.00
# Time:                        05:51:12   Log-Likelihood:                         -1528.7
# No. Observations:                 506   AIC:                                      3075.
# Df Residuals:                     497   BIC:                                      3113.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
data = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")
X=data[['crim',"zn","indus","chas","nox","rm",'age','dis','rad','tax','ptratio','b','lstat']]
y=data['medv']
model_all=sm.OLS(y,X).fit()
print(model_all.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              891.3
# Date:                Sun, 23 Aug 2026   Prob (F-statistic):                        0.00
# Time:                        06:06:10   Log-Likelihood:                         -1523.8
# No. Observations:                 506   AIC:                                      3074.
# Df Residuals:                     493   BIC:                                      3128.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=[]
X=data.iloc[:,:data.shape[1]-1]
for i in range(X.shape[1]):
  vif.append(variance_inflation_factor(X,i))

pd.DataFrame({'vif':vif},index=X.columns).T
# Out:
#          crim        zn      indus      chas        nox         rm       age  \
# vif  2.100373  2.844013  14.485758  1.152952  73.894947  77.948283  21.38685
#
#            dis        rad        tax    ptratio          b      lstat
# vif  14.699652  15.167725  61.227274  85.029547  20.104943  11.102025

# %%
data=data.drop(columns='ptratio')

# %%
X=data[['crim',"zn","indus","chas","nox","rm",'age','dis','rad','tax','b','lstat']]
y=data['medv']
model_all=sm.OLS(y,X).fit()
print(model_all.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared (uncentered):                   0.958
# Model:                            OLS   Adj. R-squared (uncentered):              0.957
# Method:                 Least Squares   F-statistic:                              942.1
# Date:                Sun, 23 Aug 2026   Prob (F-statistic):                        0.00
# Time:                        06:46:25   Log-Likelihood:                         -1530.2
# No. Observations:                 506   AIC:                                      3084.
# Df Residuals:                     494   BIC:                                      3135.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
